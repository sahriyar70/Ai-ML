# %%
number = [10, 20, 30, 40, 50, 60, 70, 80, ]

# %% [markdown]
# prothom 3 ta element ber koro

# %%
number = [10, 20, 30, 40, 50, 60, 70, 80, 9]
print(number)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 9]

# %%
number[:3]
# Out:
# [10, 20, 30]

# %% [markdown]
# seser 2 ta element berkoro

# %%
number[-2:]
# Out:
# [80, 9]

# %% [markdown]
# majher element ber koro

# %%
number[3:5]
# Out:
# [40, 50]

# %%
number[-9:]
# Out:
# [9, 80, 70, 60, 50, 40, 30, 20, 10]

# %% [markdown]
# proti 2 kore step neo

# %%
number[1:8:2]
# Out:
# [80, 60, 40, 20]

# %%
number[-8:]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
number[1:8:2]
# Out:
# [80, 60, 40, 20]

# %% [markdown]
# 2nd index theke ses porjonto

# %%
number[3:]
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
number[:4]
# Out:
# [9, 80, 70, 60]

# %%
number[1::]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
new_list = number[:]
print(new_list)
# Out:
# [9, 80, 70, 60, 50, 40, 30, 20, 10]

# %%
new_list[1:4][::-1]
# Out:
# [60, 70, 80]
